# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import time

# %%
# hyperparameters
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 1800
eval_interval = 10
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 100
n_embd = 256
n_head = 8
n_layer = 8
dropout = 0.0
print(device)
# ------------
# Out:
# cuda

# %%
torch.manual_seed(1337)

with open("/content/drive/MyDrive/Colab Notebooks/shayri_dataset.txt", 'r', encoding='utf-8') as f:
    text = f.read()
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)

# %%
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# %%
# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.99*len(data)) # first 99% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')
# Out:
# 6.415433 M parameters

# %%
# create a PyTorch optimizer
start=time.time()
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

end=time.time()
print(end-start)
# Out:
# step 0: train loss 4.4274, val loss 4.4448
# step 10: train loss 3.0103, val loss 3.0034
# step 20: train loss 2.6508, val loss 2.6367
# step 30: train loss 2.5274, val loss 2.5104
# step 40: train loss 2.4759, val loss 2.4577
# step 50: train loss 2.4474, val loss 2.4332
# step 60: train loss 2.4286, val loss 2.4084
# step 70: train loss 2.4183, val loss 2.4021
# step 80: train loss 2.4104, val loss 2.3999
# step 90: train loss 2.4021, val loss 2.3837
# step 100: train loss 2.3984, val loss 2.3834
# step 110: train loss 2.3917, val loss 2.3730
# step 120: train loss 2.3910, val loss 2.3710
# step 130: train loss 2.3866, val loss 2.3756
# step 140: train loss 2.3864, val loss 2.3676
# step 150: train loss 2.3801, val loss 2.3614
# step 160: train loss 2.3747, val loss 2.3577
# step 170: train loss 2.3698, val loss 2.3495
# step 180: train loss 2.3667, val loss 2.3463
# step 190: train loss 2.3631, val loss 2.3472
# step 200: train loss 2.3597, val loss 2.3430
# step 210: train loss 2.3586, val loss 2.3409
# step 220: train loss 2.3478, val loss 2.3329
# step 230: train loss 2.3482, val loss 2.3403
# step 240: train loss 2.3382, val loss 2.3169
# step 250: train loss 2.3333, val loss 2.3119
# step 260: train loss 2.3251, val loss 2.3087
# step 270: train loss 2.3240, val loss 2.3019
# step 280: train loss 2.3157, val loss 2.2979
# step 290: train loss 2.3116, val loss 2.2886
# step 300: train loss 2.3047, val loss 2.2772
# step 310: train loss 2.2964, val loss 2.2792
# step 320: train loss 2.2855, val loss 2.2665
# step 330: train loss 2.2777, val loss 2.2640
# step 340: train loss 2.2605, val loss 2.2422
# step 350: train loss 2.2470, val loss 2.2298
# step 360: train loss 2.2358, val loss 2.2233
# step 370: train loss 2.2175, val loss 2.2053
# step 380: train loss 2.1939, val loss 2.1907
# step 390: train loss 2.1720, val loss 2.1620
# step 400: train loss 2.1537, val loss 2.1444
# step 410: train loss 2.1244, val loss 2.1093
# step 420: train loss 2.0855, val loss 2.0817
# step 430: train loss 2.0605, val loss 2.0667
# step 440: train loss 2.0258, val loss 2.0234
# step 450: train loss 1.9880, val loss 2.0085
# step 460: train loss 1.9634, val loss 1.9824
# step 470: train loss 1.9485, val loss 1.9683
# step 480: train loss 1.9238, val loss 1.9508
# step 490: train loss 1.8939, val loss 1.9203
# step 500: train loss 1.8712, val loss 1.9113
# step 510: train loss 1.8453, val loss 1.8780
# step 520: train loss 1.8369, val loss 1.8717
# step 530: train loss 1.8181, val loss 1.8602
# step 540: train loss 1.7937, val loss 1.8458
# step 550: train loss 1.7894, val loss 1.8308
# step 560: train loss 1.7674, val loss 1.8208
# step 570: train loss 1.7494, val loss 1.8032
# step 580: train loss 1.7325, val loss 1.7983
# step 590: train loss 1.7199, val loss 1.7820
# step 600: train loss 1.7052, val loss 1.7806
# step 610: train loss 1.6966, val loss 1.7757
# step 620: train loss 1.6775, val loss 1.7588
# step 630: train loss 1.6734, val loss 1.7499
# step 640: train loss 1.6637, val loss 1.7336
# step 650: train loss 1.6493, val loss 1.7162
# step 660: train loss 1.6369, val loss 1.7175
# step 670: train loss 1.6254, val loss 1.7063
# step 680: train loss 1.6248, val loss 1.7093
# step 690: train loss 1.6133, val loss 1.6919
# step 700: train loss 1.5924, val loss 1.6830
# step 710: train loss 1.5853, val loss 1.6739
# step 720: train loss 1.5749, val loss 1.6625
# step 730: train loss 1.5729, val loss 1.6550
# step 740: train loss 1.5672, val loss 1.6621
# step 750: train loss 1.5502, val loss 1.6402
# step 760: train loss 1.5476, val loss 1.6349
# step 770: train loss 1.5430, val loss 1.6355
# step 780: train loss 1.5380, val loss 1.6241
# step 790: train loss 1.5260, val loss 1.6238
# step 800: train loss 1.5173, val loss 1.6083
# step 810: train loss 1.5183, val loss 1.6021
# step 820: train loss 1.5026, val loss 1.6075
# step 830: train loss 1.5048, val loss 1.5994
# step 840: train loss 1.4947, val loss 1.5963
# step 850: train loss 1.4746, val loss 1.5865
# step 860: train loss 1.4717, val loss 1.5732
# step 870: train loss 1.4706, val loss 1.5805
# step 880: train loss 1.4709, val loss 1.5866
# step 890: train loss 1.4579, val loss 1.5687
# step 900: train loss 1.4470, val loss 1.5551
# step 910: train loss 1.4429, val loss 1.5655
# step 920: train loss 1.4401, val loss 1.5529
# step 930: train loss 1.4324, val loss 1.5664
# step 940: train loss 1.4338, val loss 1.5551
# step 950: train loss 1.4253, val loss 1.5534
# step 960: train loss 1.4152, val loss 1.5505
# step 970: train loss 1.4087, val loss 1.5428
# step 980: train loss 1.4155, val loss 1.5402
# step 990: train loss 1.3929, val loss 1.5378
# step 1000: train loss 1.3853, val loss 1.5258
# step 1010: train loss 1.3808, val loss 1.5296
# step 1020: train loss 1.3842, val loss 1.5344
# step 1030: train loss 1.3835, val loss 1.5332
# step 1040: train loss 1.3718, val loss 1.5133
# step 1050: train loss 1.3636, val loss 1.5113
# step 1060: train loss 1.3634, val loss 1.4999
# step 1070: train loss 1.3468, val loss 1.4877
# step 1080: train loss 1.3467, val loss 1.5114
# step 1090: train loss 1.3416, val loss 1.4784
# step 1100: train loss 1.3341, val loss 1.4762
# step 1110: train loss 1.3300, val loss 1.4924
# step 1120: train loss 1.3258, val loss 1.5041
# step 1130: train loss 1.3203, val loss 1.5111
# step 1140: train loss 1.3147, val loss 1.4977
# step 1150: train loss 1.3060, val loss 1.5005
# step 1160: train loss 1.3037, val loss 1.4971
# step 1170: train loss 1.2857, val loss 1.4972
# step 1180: train loss 1.2959, val loss 1.4804
# step 1190: train loss 1.2821, val loss 1.4766
# step 1200: train loss 1.2770, val loss 1.4814
# step 1210: train loss 1.2684, val loss 1.4785
# step 1220: train loss 1.2647, val loss 1.4746
# step 1230: train loss 1.2620, val loss 1.4859
# step 1240: train loss 1.2467, val loss 1.4840
# step 1250: train loss 1.2415, val loss 1.4657
# step 1260: train loss 1.2397, val loss 1.4601
# step 1270: train loss 1.2288, val loss 1.4552
# step 1280: train loss 1.2331, val loss 1.4417
# step 1290: train loss 1.2187, val loss 1.4666
# step 1300: train loss 1.2163, val loss 1.4783
# step 1310: train loss 1.2109, val loss 1.4459
# step 1320: train loss 1.1978, val loss 1.4429
# step 1330: train loss 1.1929, val loss 1.4642
# step 1340: train loss 1.1962, val loss 1.4545
# step 1350: train loss 1.1860, val loss 1.4556
# step 1360: train loss 1.1706, val loss 1.4431
# step 1370: train loss 1.1684, val loss 1.4446
# step 1380: train loss 1.1667, val loss 1.4531
# step 1390: train loss 1.1673, val loss 1.4675
# step 1400: train loss 1.1477, val loss 1.4576
# step 1410: train loss 1.1404, val loss 1.4549
# step 1420: train loss 1.1415, val loss 1.4529
# step 1430: train loss 1.1258, val loss 1.4551
# step 1440: train loss 1.1308, val loss 1.4671
# step 1450: train loss 1.1226, val loss 1.4628
# step 1460: train loss 1.1139, val loss 1.4478
# step 1470: train loss 1.1062, val loss 1.4604
# step 1480: train loss 1.0919, val loss 1.4722
# step 1490: train loss 1.0825, val loss 1.4755
# step 1500: train loss 1.0886, val loss 1.4628
# step 1510: train loss 1.0811, val loss 1.4556
# step 1520: train loss 1.0716, val loss 1.4713
# step 1530: train loss 1.0617, val loss 1.4382
# step 1540: train loss 1.0502, val loss 1.4349
# step 1550: train loss 1.0476, val loss 1.4656
# step 1560: train loss 1.0490, val loss 1.4502
# step 1570: train loss 1.0315, val loss 1.4559
# step 1580: train loss 1.0326, val loss 1.4507
# step 1590: train loss 1.0159, val loss 1.4577
# step 1600: train loss 1.0193, val loss 1.4677
# step 1610: train loss 1.0051, val loss 1.4630
# step 1620: train loss 0.9955, val loss 1.4765
# step 1630: train loss 0.9964, val loss 1.4778
# step 1640: train loss 0.9817, val loss 1.4735
# step 1650: train loss 0.9810, val loss 1.4850
# step 1660: train loss 0.9780, val loss 1.4967
# step 1670: train loss 0.9562, val loss 1.4719
# step 1680: train loss 0.9513, val loss 1.4738
# step 1690: train loss 0.9446, val loss 1.4703
# step 1700: train loss 0.9373, val loss 1.4796
# step 1710: train loss 0.9286, val loss 1.4653
# step 1720: train loss 0.9173, val loss 1.4770
# step 1730: train loss 0.9220, val loss 1.4424
# step 1740: train loss 0.9073, val loss 1.4590
# step 1750: train loss 0.9029, val loss 1.4553
# step 1760: train loss 0.9021, val loss 1.4485
# step 1770: train loss 0.8904, val loss 1.4623
# step 1780: train loss 0.8897, val loss 1.4496
# step 1790: train loss 0.8709, val loss 1.4355
# step 1799: train loss 0.8623, val loss 1.4366
# 3020.6947634220123

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=200)[0].tolist()))
# Out:
# आदमी है मिल के आदमी अदम
# जो भी मंज़िल पे भी इंसान की नहीं ।
# दोस्तों दुश्मनों ने फ़स्सों न बनाया
# दो-चार दिया तो मेहर-ए-पौदा तरफ़ टूटा ।
# मैं अब तल्ख़ तरह दिखाते हैं
# भूके रस्ते हुए हँसते ऑते ।
# बिछड़ के

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=200)[0].tolist()))
# Out:
# हम हैं जो प्यास की ही सिफठती रहती
# हम से ज़मीं पाँध नहीं देखा जाए ।
# शिकस्त के ये हैं चमन का बदल है
# कि हती चेहरे में लौट रहा है ।
# 'तौबा' के माथे में गई ये चेहरो की धूप
# यही मत इस शहर में तो धर से उधर
